# %% [markdown]
# ##**Code Section**##
#
# - Colab Environment Setting
#
# - Data Augmentation
#  - file 구조(/dataset/{건물 방향 class label}/{integer}.jpg)
# - Model
#  - Pretrained model (데규모 데이터셋으로 학습된 특징 내포, 특징 추출의 일반화가능)
#  - Resnet18 이용(작은 모델, 적은 데이터로도 overfitting 되지 않음)
# - Train
# - Test
#
#
# <br>
#
# **Training Section**
#
# 1. sub-class 없이 여러면의 사진을 전부 하나의 class로 학습시키고 test
#
# 2. sub-class만을 이용하여 학습 시키기
#
#  - test 시에 sub-class 합을 이용
#  - test 시에 각 sub-class를 이용
#
# 3. 각 건물의 sub-class 합을 통해 학습시키고 test

# %% [markdown]
# ## **Colab Env Setting**

# %%
# Mount Google Drive in /content/drive directory

from google.colab import drive
drive.mount('/content/drive')

# Change current directory

import os
os.chdir('/content/drive/MyDrive/Project')
# Out:
# Mounted at /content/drive

# %%
##### DO NOT MODIFY #####
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader

import torchvision
import torchvision.transforms as transforms
import numpy
import cv2
from google.colab.patches import cv2_imshow
##### DO NOT MODIFY #####

# %%
import torch

print(torch.cuda.is_available())
# Out:
# True

# %%
# !pip install pyheif
# !pip install opencv-python
# Out:
# Collecting pyheif
#   Downloading pyheif-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.7 kB)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pyheif) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.0->pyheif) (2.22)
# Downloading pyheif-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 23.7 MB/s eta 0:00:00
# Installing collected packages: pyheif
# Successfully installed pyheif-0.8.0
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.26.4)

# %% [markdown]
# ## **Data Preprocessing and Augmentation**

# %%
# %%writefile building_info.py
building_label_to_name = {
    1: "정문안내소(정면)",
    2: "보노보노",
    3: "커뮤니티센터",
    4: "토르망치",
    5: "201동 본관",
    6: "101동",
    7: "103동",
    8: "105동",
    9: "107동",
    10: "109동",
    11: "114동 경영관",
    12: "203동 학관",
    13: "205동 스센",
    14: "다리 1(담배다리)",
    15: "다리 4(버정옆)",
    16: "다리 5(고래다리)",
    17: "다리 6(테니스장앞)",
    18: "대운",
    19: "바보계단",
    20: "이차전지 산학연 연구센터",
    21: "해수자원화기술 연구센터",
    22: "복합재료기술 연구센터",
    23: "산학협력관",
    24: "과일집",
    25: "거리변위다리",
    26: "식당동",
    27: "오렌지다리",
    28: "학술정보관"
}
class_to_building_label = {
    0: 1,
    1: 1,
    2: 1,
    3: 2,
    4: 3,
    5: 4,
    6: 4,
    7: 5,
    8: 5,
    9: 5,
    10: 5,
    11: 6,
    12: 6,
    13: 6,
    14: 6,
    15: 7,
    16: 7,
    17: 7,
    18: 7,
    19: 8,
    20: 8,
    21: 8,
    22: 8,
    23: 9,
    24: 9,
    25: 9,
    26: 10,
    27: 10,
    28: 10,
    29: 10,
    30: 11,	#114 경영관(정면)
    31: 11,	#114 경영관(우측)
    32: 11,	#114 경영관(뒷면)
    33: 11,	#114 경영관(좌측)
    34: 12,	#203 학관(정면)
    35: 12,	#203 학관(옆면)
    36: 12,	#203 학관(뒷면)
    37: 13,	#205 스센(정면)
    38: 13,	#205 스센(좌측)
    39: 13,	#205 스센(뒷면)
    40: 13,	#205 스센(우측)
    41: 14,	#담배다리(기숙사쪽)
    42: 14,	#담배다리(스센쪽)
    43: 15,	#본관옆 다리(본관쪽)
    44: 15,	#본관옆 다리(대운쪽)
    45: 16,	#고래다리(출구)
    46: 16,	#고래다리(입구)
    47: 17,	#테니스장다리(테니스장쪽)
    48: 17,	#테니스장다리(테니스장기준우측)
    49: 17,	#테니스장다리(스센쪽)
    50: 17,	#테니스장다리(테니스장기준 좌측)
    51: 18,	#대운(트랙나옴)
    52: 18,	#대운(트랙안나옴)
    53: 19,	#바보계단(경영관쪽)
    54: 19,	#바보계단(스센쪽)
    55: 19,	#바보계단(학관쪽)
    56: 20,		#111 이차전지 산학연 연구센터
    57: 20,		#111 이차전지 산학연 연구센터
    58: 20,		#111 이차전지 산학연 연구센터
    59: 20,		#111 이차전지 산학연 연구센터
    60: 21,		#113 해수자원화기술 연구센터
    61: 21,		#113 해수자원화기술 연구센터
    62: 21,		#113 해수자원화기술 연구센터
    63: 21,		#113 해수자원화기술 연구센터
    64: 22,		#123 복합재료기술 연구센터
    65: 22,		#123 복합재료기술 연구센터
    66: 22,		#123 복합재료기술 연구센터
    67: 22,		#123 복합재료기술 연구센터
    68: 23,		#251 산학협력관
    69: 23,		#251 산학협력관
    70: 23,		#251 산학협력관
    71: 23,		#251 산학협력관
    72: 24,		#125 과일집
    73: 24,		#125 과일집
    74: 24,		#125 과일집
    75: 24,		#125 과일집
    76: 25,		#거리변위다리
    77: 25,		#거리변위다리
    78: 26,		#206 식당동
    79: 26,		#206 식당동
    80: 26,		#206 식당동
    81: 26,		#206 식당동
    82: 27,		#오렌지다리
    83: 27,		#오렌지다리
    84: 28,		#202 학술정보관
    85: 28,		#202 학술정보관
    86: 28,		#202 학술정보관
    87: 28		#202 학술정보관
}

def get_building_name(label_num):
  return building_label_to_name.get(label_num, "Unknown")

def get_building_label(class_num):
  return class_to_building_label.get(class_num, "Unknown Building")

num_classes = 88
dataset_path = './dataset'
# Out:
# Overwriting building_info.py

# %%
# Preprocessing, JPG, HEIC -> .jpg and 이미지 이름 0.jpg, 1.jpg ... 로 변경

import os
from pathlib import Path
from PIL import Image
import pyheif  # pyheif 라이브러리 추가


num_classes = 88
dataset_path = './dataset'



# 이미지를 .jpg로 변환하는 함수
def convert_image_to_jpg(image_path, output_path):
    try:
        # HEIC 파일인 경우 pyheif를 사용하여 변환
        if image_path.suffix.lower() == '.heic':
            heif_file = pyheif.read(image_path)  # HEIC 파일 읽기
            img = Image.frombytes(
                heif_file.mode,
                heif_file.size,
                heif_file.data,
                "raw",
                heif_file.mode,
                heif_file.stride
            )
        else:
            img = Image.open(image_path)  # HEIC 외의 파일은 PIL로 열기

        img.convert('RGB').save(output_path, 'JPEG')  # .jpg로 저장
        print(f"변환 완료: {image_path} -> {output_path}")
    except Exception as e:
        print(f"이미지 변환 중 오류 발생: {image_path}, {e}")

# 폴더 내 이미지 파일 이름 변경 및 포맷 변환
def rename_images_in_folder(folder_path):
    folder = Path(folder_path)

    if not folder.exists() or not folder.is_dir():
        print(f"폴더가 존재하지 않거나 유효하지 않습니다: {folder_path}")
        return

    image_files = [f for f in folder.iterdir() if f.is_file()]

    for idx, image_file in enumerate(image_files):
        # 새로운 파일명 생성 (0.jpg, 1.jpg, ...)
        new_name = f"{idx}.jpg"
        new_path = folder / new_name

        # 이미지 파일을 .jpg로 변환 후 저장
        convert_image_to_jpg(image_file, new_path)

    print("이름 변경 및 포맷 변환 완료.")

# 예시로 dataset_path와 num_classes가 이미 정의되어 있다고 가정
for i in range(num_classes):
    path = f'{dataset_path}/{str(i)}'
    print(path)
    rename_images_in_folder(path)
# Out:
# ./dataset/0
# 변환 완료: dataset/0/IMG_8404.JPG -> dataset/0/0.jpg
# 변환 완료: dataset/0/IMG_8405.JPG -> dataset/0/1.jpg
# 변환 완료: dataset/0/IMG_8402.JPG -> dataset/0/2.jpg
# 변환 완료: dataset/0/IMG_8403.JPG -> dataset/0/3.jpg
# 변환 완료: dataset/0/IMG_8399.JPG -> dataset/0/4.jpg
# 변환 완료: dataset/0/IMG_8401.JPG -> dataset/0/5.jpg
# 변환 완료: dataset/0/IMG_8400.JPG -> dataset/0/6.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/1
# 변환 완료: dataset/1/IMG_8421.JPG -> dataset/1/0.jpg
# 변환 완료: dataset/1/IMG_8415.JPG -> dataset/1/1.jpg
# 변환 완료: dataset/1/IMG_8422.JPG -> dataset/1/2.jpg
# 변환 완료: dataset/1/IMG_8406.JPG -> dataset/1/3.jpg
# 변환 완료: dataset/1/IMG_8418.JPG -> dataset/1/4.jpg
# 변환 완료: dataset/1/IMG_8412.JPG -> dataset/1/5.jpg
# 변환 완료: dataset/1/IMG_8414.JPG -> dataset/1/6.jpg
# 변환 완료: dataset/1/IMG_8411.JPG -> dataset/1/7.jpg
# 변환 완료: dataset/1/IMG_8407.JPG -> dataset/1/8.jpg
# 변환 완료: dataset/1/IMG_8416.JPG -> dataset/1/9.jpg
# 변환 완료: dataset/1/IMG_8408.JPG -> dataset/1/10.jpg
# 변환 완료: dataset/1/IMG_8410.JPG -> dataset/1/11.jpg
# 변환 완료: dataset/1/IMG_8420.JPG -> dataset/1/12.jpg
# 변환 완료: dataset/1/IMG_8413.JPG -> dataset/1/13.jpg
# 변환 완료: dataset/1/IMG_8419.JPG -> dataset/1/14.jpg
# 변환 완료: dataset/1/IMG_8409.JPG -> dataset/1/15.jpg
# 변환 완료: dataset/1/IMG_8417.JPG -> dataset/1/16.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/2
# 변환 완료: dataset/2/IMG_8388.JPG -> dataset/2/0.jpg
# 변환 완료: dataset/2/IMG_8390.JPG -> dataset/2/1.jpg
# 변환 완료: dataset/2/IMG_8386.JPG -> dataset/2/2.jpg
# 변환 완료: dataset/2/IMG_8391.JPG -> dataset/2/3.jpg
# 변환 완료: dataset/2/IMG_8389.JPG -> dataset/2/4.jpg
# 변환 완료: dataset/2/IMG_8387.JPG -> dataset/2/5.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/3
# 변환 완료: dataset/3/IMG_5960.HEIC -> dataset/3/0.jpg
# 변환 완료: dataset/3/IMG_5932.HEIC -> dataset/3/1.jpg
# 변환 완료: dataset/3/IMG_5912.HEIC -> dataset/3/2.jpg
# 변환 완료: dataset/3/IMG_5918.HEIC -> dataset/3/3.jpg
# 변환 완료: dataset/3/IMG_5931.HEIC -> dataset/3/4.jpg
# 변환 완료: dataset/3/IMG_5924.HEIC -> dataset/3/5.jpg
# 변환 완료: dataset/3/IMG_5941.HEIC -> dataset/3/6.jpg
# 변환 완료: dataset/3/IMG_5942.HEIC -> dataset/3/7.jpg
# 변환 완료: dataset/3/IMG_5906.HEIC -> dataset/3/8.jpg
# 변환 완료: dataset/3/IMG_5910.HEIC -> dataset/3/9.jpg
# 변환 완료: dataset/3/IMG_5919.HEIC -> dataset/3/10.jpg
# 변환 완료: dataset/3/IMG_5948.HEIC -> dataset/3/11.jpg
# 변환 완료: dataset/3/IMG_5945.HEIC -> dataset/3/12.jpg
# 변환 완료: dataset/3/IMG_5926.HEIC -> dataset/3/13.jpg
# 변환 완료: dataset/3/IMG_5904.HEIC -> dataset/3/14.jpg
# 변환 완료: dataset/3/IMG_5934.HEIC -> dataset/3/15.jpg
# 변환 완료: dataset/3/IMG_5954.HEIC -> dataset/3/16.jpg
# 변환 완료: dataset/3/IMG_5956.HEIC -> dataset/3/17.jpg
# 변환 완료: dataset/3/IMG_5521.JPG -> dataset/3/18.jpg
# 변환 완료: dataset/3/IMG_5911.HEIC -> dataset/3/19.jpg
# 변환 완료: dataset/3/IMG_5917.HEIC -> dataset/3/20.jpg
# 변환 완료: dataset/3/IMG_5958.HEIC -> dataset/3/21.jpg
# 변환 완료: dataset/3/IMG_5520.JPG -> dataset/3/22.jpg
# 변환 완료: dataset/3/IMG_5915.HEIC -> dataset/3/23.jpg
# 변환 완료: dataset/3/IMG_5928.HEIC -> dataset/3/24.jpg
# 변환 완료: dataset/3/IMG_5963.HEIC -> dataset/3/25.jpg
# 변환 완료: dataset/3/IMG_5952.HEIC -> dataset/3/26.jpg
# 변환 완료: dataset/3/IMG_5519.JPG -> dataset/3/27.jpg
# 변환 완료: dataset/3/IMG_5905.HEIC -> dataset/3/28.jpg
# 변환 완료: dataset/3/IMG_5907.HEIC -> dataset/3/29.jpg
# 변환 완료: dataset/3/IMG_5944.HEIC -> dataset/3/30.jpg
# 변환 완료: dataset/3/IMG_5933.HEIC -> dataset/3/31.jpg
# 변환 완료: dataset/3/IMG_5916.HEIC -> dataset/3/32.jpg
# 변환 완료: dataset/3/IMG_5909.HEIC -> dataset/3/33.jpg
# 변환 완료: dataset/3/IMG_5522.JPG -> dataset/3/34.jpg
# 변환 완료: dataset/3/IMG_5923.HEIC -> dataset/3/35.jpg
# 변환 완료: dataset/3/IMG_5953.HEIC -> dataset/3/36.jpg
# 변환 완료: dataset/3/IMG_5957.HEIC -> dataset/3/37.jpg
# 변환 완료: dataset/3/IMG_5955.HEIC -> dataset/3/38.jpg
# 변환 완료: dataset/3/IMG_5908.HEIC -> dataset/3/39.jpg
# 변환 완료: dataset/3/IMG_5937.HEIC -> dataset/3/40.jpg
# 변환 완료: dataset/3/IMG_5927.HEIC -> dataset/3/41.jpg
# 변환 완료: dataset/3/IMG_5959.HEIC -> dataset/3/42.jpg
# 변환 완료: dataset/3/IMG_5939.HEIC -> dataset/3/43.jpg
# 변환 완료: dataset/3/IMG_5935.HEIC -> dataset/3/44.jpg
# 변환 완료: dataset/3/IMG_5949.HEIC -> dataset/3/45.jpg
# 변환 완료: dataset/3/IMG_5946.HEIC -> dataset/3/46.jpg
# 변환 완료: dataset/3/IMG_5921.HEIC -> dataset/3/47.jpg
# 변환 완료: dataset/3/IMG_5913.HEIC -> dataset/3/48.jpg
# 변환 완료: dataset/3/IMG_5903.HEIC -> dataset/3/49.jpg
# 변환 완료: dataset/3/IMG_5940.HEIC -> dataset/3/50.jpg
# 변환 완료: dataset/3/IMG_5938.HEIC -> dataset/3/51.jpg
# 변환 완료: dataset/3/IMG_5902.HEIC -> dataset/3/52.jpg
# 변환 완료: dataset/3/IMG_5914.HEIC -> dataset/3/53.jpg
# 변환 완료: dataset/3/IMG_5951.HEIC -> dataset/3/54.jpg
# 변환 완료: dataset/3/IMG_5964.HEIC -> dataset/3/55.jpg
# 변환 완료: dataset/3/IMG_5943.HEIC -> dataset/3/56.jpg
# 변환 완료: dataset/3/IMG_5962.HEIC -> dataset/3/57.jpg
# 변환 완료: dataset/3/IMG_5925.HEIC -> dataset/3/58.jpg
# 변환 완료: dataset/3/IMG_5947.HEIC -> dataset/3/59.jpg
# 변환 완료: dataset/3/IMG_5920.HEIC -> dataset/3/60.jpg
# 변환 완료: dataset/3/IMG_5922.HEIC -> dataset/3/61.jpg
# 변환 완료: dataset/3/IMG_5950.HEIC -> dataset/3/62.jpg
# 변환 완료: dataset/3/IMG_5961.HEIC -> dataset/3/63.jpg
# 변환 완료: dataset/3/IMG_5929.HEIC -> dataset/3/64.jpg
# 변환 완료: dataset/3/IMG_5930.HEIC -> dataset/3/65.jpg
# 변환 완료: dataset/3/IMG_5936.HEIC -> dataset/3/66.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/4
# 변환 완료: dataset/4/IMG_5495.JPG -> dataset/4/0.jpg
# 변환 완료: dataset/4/IMG_5496.JPG -> dataset/4/1.jpg
# 변환 완료: dataset/4/IMG_5497.JPG -> dataset/4/2.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/5
# 변환 완료: dataset/5/IMG_6156.HEIC -> dataset/5/0.jpg
# 변환 완료: dataset/5/IMG_5489.JPG -> dataset/5/1.jpg
# 변환 완료: dataset/5/IMG_6155.HEIC -> dataset/5/2.jpg
# 변환 완료: dataset/5/IMG_6157.HEIC -> dataset/5/3.jpg
# 변환 완료: dataset/5/IMG_6158.HEIC -> dataset/5/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/6
# 변환 완료: dataset/6/IMG_5487.JPG -> dataset/6/0.jpg
# 변환 완료: dataset/6/IMG_6159.HEIC -> dataset/6/1.jpg
# 변환 완료: dataset/6/IMG_6160.HEIC -> dataset/6/2.jpg
# 변환 완료: dataset/6/IMG_6165.HEIC -> dataset/6/3.jpg
# 변환 완료: dataset/6/IMG_6164.HEIC -> dataset/6/4.jpg
# 변환 완료: dataset/6/IMG_5490.JPG -> dataset/6/5.jpg
# 변환 완료: dataset/6/IMG_5488.JPG -> dataset/6/6.jpg
# 변환 완료: dataset/6/IMG_6163.HEIC -> dataset/6/7.jpg
# 변환 완료: dataset/6/IMG_6166.HEIC -> dataset/6/8.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/7
# 변환 완료: dataset/7/IMG_8365.JPG -> dataset/7/0.jpg
# 변환 완료: dataset/7/IMG_8366.JPG -> dataset/7/1.jpg
# 변환 완료: dataset/7/IMG_8368.JPG -> dataset/7/2.jpg
# 변환 완료: dataset/7/IMG_8370.JPG -> dataset/7/3.jpg
# 변환 완료: dataset/7/IMG_5491.JPG -> dataset/7/4.jpg
# 변환 완료: dataset/7/IMG_8369.JPG -> dataset/7/5.jpg
# 변환 완료: dataset/7/IMG_8367.JPG -> dataset/7/6.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/8
# 변환 완료: dataset/8/IMG_8350.JPG -> dataset/8/0.jpg
# 변환 완료: dataset/8/IMG_5494.JPG -> dataset/8/1.jpg
# 변환 완료: dataset/8/IMG_8346.JPG -> dataset/8/2.jpg
# 변환 완료: dataset/8/IMG_8349.JPG -> dataset/8/3.jpg
# 변환 완료: dataset/8/IMG_8348.JPG -> dataset/8/4.jpg
# 변환 완료: dataset/8/IMG_8347.JPG -> dataset/8/5.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/9
# 변환 완료: dataset/9/IMG_8363.JPG -> dataset/9/0.jpg
# 변환 완료: dataset/9/IMG_8360.JPG -> dataset/9/1.jpg
# 변환 완료: dataset/9/IMG_8358.JPG -> dataset/9/2.jpg
# 변환 완료: dataset/9/IMG_8357.JPG -> dataset/9/3.jpg
# 변환 완료: dataset/9/IMG_8362.JPG -> dataset/9/4.jpg
# 변환 완료: dataset/9/IMG_8359.JPG -> dataset/9/5.jpg
# 변환 완료: dataset/9/IMG_5492.JPG -> dataset/9/6.jpg
# 변환 완료: dataset/9/IMG_8361.JPG -> dataset/9/7.jpg
# 변환 완료: dataset/9/IMG_8364.JPG -> dataset/9/8.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/10
# 변환 완료: dataset/10/IMG_8344.JPG -> dataset/10/0.jpg
# 변환 완료: dataset/10/IMG_8351.JPG -> dataset/10/1.jpg
# 변환 완료: dataset/10/IMG_8355.JPG -> dataset/10/2.jpg
# 변환 완료: dataset/10/IMG_8353.JPG -> dataset/10/3.jpg
# 변환 완료: dataset/10/IMG_8354.JPG -> dataset/10/4.jpg
# 변환 완료: dataset/10/IMG_8352.JPG -> dataset/10/5.jpg
# 변환 완료: dataset/10/IMG_8356.JPG -> dataset/10/6.jpg
# 변환 완료: dataset/10/IMG_5493.JPG -> dataset/10/7.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/11
# 변환 완료: dataset/11/IMG_6167.HEIC -> dataset/11/0.jpg
# 변환 완료: dataset/11/IMG_8380.JPG -> dataset/11/1.jpg
# 변환 완료: dataset/11/IMG_8385.JPG -> dataset/11/2.jpg
# 변환 완료: dataset/11/IMG_8381.JPG -> dataset/11/3.jpg
# 변환 완료: dataset/11/IMG_6172.HEIC -> dataset/11/4.jpg
# 변환 완료: dataset/11/IMG_5499.JPG -> dataset/11/5.jpg
# 변환 완료: dataset/11/IMG_8383.JPG -> dataset/11/6.jpg
# 변환 완료: dataset/11/IMG_6171.HEIC -> dataset/11/7.jpg
# 변환 완료: dataset/11/IMG_6170.HEIC -> dataset/11/8.jpg
# 변환 완료: dataset/11/IMG_8378.JPG -> dataset/11/9.jpg
# 변환 완료: dataset/11/IMG_8382.JPG -> dataset/11/10.jpg
# 변환 완료: dataset/11/IMG_6174.HEIC -> dataset/11/11.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/12
# 변환 완료: dataset/12/IMG_5502.JPG -> dataset/12/0.jpg
# 변환 완료: dataset/12/IMG_6099.HEIC -> dataset/12/1.jpg
# 변환 완료: dataset/12/IMG_6110.HEIC -> dataset/12/2.jpg
# 변환 완료: dataset/12/IMG_6113.HEIC -> dataset/12/3.jpg
# 변환 완료: dataset/12/IMG_6107.HEIC -> dataset/12/4.jpg
# 변환 완료: dataset/12/IMG_6109.HEIC -> dataset/12/5.jpg
# 변환 완료: dataset/12/IMG_6100.HEIC -> dataset/12/6.jpg
# 변환 완료: dataset/12/IMG_6101.HEIC -> dataset/12/7.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/13
# 변환 완료: dataset/13/IMG_6080.HEIC -> dataset/13/0.jpg
# 변환 완료: dataset/13/IMG_6094.HEIC -> dataset/13/1.jpg
# 변환 완료: dataset/13/IMG_6091.HEIC -> dataset/13/2.jpg
# 변환 완료: dataset/13/IMG_6142.HEIC -> dataset/13/3.jpg
# 변환 완료: dataset/13/IMG_6087.HEIC -> dataset/13/4.jpg
# 변환 완료: dataset/13/IMG_5500.JPG -> dataset/13/5.jpg
# 변환 완료: dataset/13/IMG_6077.HEIC -> dataset/13/6.jpg
# 변환 완료: dataset/13/IMG_6089.HEIC -> dataset/13/7.jpg
# 변환 완료: dataset/13/IMG_6093.HEIC -> dataset/13/8.jpg
# 변환 완료: dataset/13/IMG_6090.HEIC -> dataset/13/9.jpg
# 변환 완료: dataset/13/IMG_6082.HEIC -> dataset/13/10.jpg
# 변환 완료: dataset/13/IMG_6139.HEIC -> dataset/13/11.jpg
# 변환 완료: dataset/13/IMG_6138.HEIC -> dataset/13/12.jpg
# 변환 완료: dataset/13/IMG_6092.HEIC -> dataset/13/13.jpg
# 변환 완료: dataset/13/IMG_8379.JPG -> dataset/13/14.jpg
# 변환 완료: dataset/13/IMG_6083.HEIC -> dataset/13/15.jpg
# 변환 완료: dataset/13/IMG_6141.HEIC -> dataset/13/16.jpg
# 변환 완료: dataset/13/IMG_6140.HEIC -> dataset/13/17.jpg
# 변환 완료: dataset/13/IMG_6081.HEIC -> dataset/13/18.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/14
# 변환 완료: dataset/14/IMG_6088.HEIC -> dataset/14/0.jpg
# 변환 완료: dataset/14/IMG_6133.HEIC -> dataset/14/1.jpg
# 변환 완료: dataset/14/IMG_6136.HEIC -> dataset/14/2.jpg
# 변환 완료: dataset/14/IMG_6125.HEIC -> dataset/14/3.jpg
# 변환 완료: dataset/14/IMG_6132.HEIC -> dataset/14/4.jpg
# 변환 완료: dataset/14/IMG_8377.JPG -> dataset/14/5.jpg
# 변환 완료: dataset/14/IMG_6129.HEIC -> dataset/14/6.jpg
# 변환 완료: dataset/14/IMG_6131.HEIC -> dataset/14/7.jpg
# 변환 완료: dataset/14/IMG_6135.HEIC -> dataset/14/8.jpg
# 변환 완료: dataset/14/IMG_6128.HEIC -> dataset/14/9.jpg
# 변환 완료: dataset/14/IMG_6137.HEIC -> dataset/14/10.jpg
# 변환 완료: dataset/14/IMG_6134.HEIC -> dataset/14/11.jpg
# 변환 완료: dataset/14/IMG_5501.JPG -> dataset/14/12.jpg
# 변환 완료: dataset/14/IMG_6124.HEIC -> dataset/14/13.jpg
# 변환 완료: dataset/14/IMG_6127.HEIC -> dataset/14/14.jpg
# 변환 완료: dataset/14/IMG_6130.HEIC -> dataset/14/15.jpg
# 변환 완료: dataset/14/IMG_6126.HEIC -> dataset/14/16.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/15
# 변환 완료: dataset/15/IMG_6161.HEIC -> dataset/15/0.jpg
# 변환 완료: dataset/15/IMG_6162.HEIC -> dataset/15/1.jpg
# 변환 완료: dataset/15/IMG_5969.HEIC -> dataset/15/2.jpg
# 변환 완료: dataset/15/IMG_5965.HEIC -> dataset/15/3.jpg
# 변환 완료: dataset/15/IMG_5966.HEIC -> dataset/15/4.jpg
# 변환 완료: dataset/15/IMG_5967.HEIC -> dataset/15/5.jpg
# 변환 완료: dataset/15/IMG_5970.HEIC -> dataset/15/6.jpg
# 변환 완료: dataset/15/IMG_5968.HEIC -> dataset/15/7.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/16
# 변환 완료: dataset/16/IMG_6151.HEIC -> dataset/16/0.jpg
# 변환 완료: dataset/16/IMG_6148.HEIC -> dataset/16/1.jpg
# 변환 완료: dataset/16/IMG_6152.HEIC -> dataset/16/2.jpg
# 변환 완료: dataset/16/IMG_5505.JPG -> dataset/16/3.jpg
# 변환 완료: dataset/16/IMG_6149.HEIC -> dataset/16/4.jpg
# 변환 완료: dataset/16/IMG_6150.HEIC -> dataset/16/5.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/17
# 변환 완료: dataset/17/IMG_6076.HEIC -> dataset/17/0.jpg
# 변환 완료: dataset/17/IMG_6085.HEIC -> dataset/17/1.jpg
# 변환 완료: dataset/17/IMG_6084.HEIC -> dataset/17/2.jpg
# 변환 완료: dataset/17/IMG_6086.HEIC -> dataset/17/3.jpg
# 변환 완료: dataset/17/IMG_6078.HEIC -> dataset/17/4.jpg
# 변환 완료: dataset/17/IMG_6079.HEIC -> dataset/17/5.jpg
# 변환 완료: dataset/17/IMG_5506.JPG -> dataset/17/6.jpg
# 변환 완료: dataset/17/IMG_6074.HEIC -> dataset/17/7.jpg
# 변환 완료: dataset/17/IMG_6075.HEIC -> dataset/17/8.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/18
# 변환 완료: dataset/18/IMG_5504.JPG -> dataset/18/0.jpg
# 변환 완료: dataset/18/IMG_8374.JPG -> dataset/18/1.jpg
# 변환 완료: dataset/18/IMG_5972.HEIC -> dataset/18/2.jpg
# 변환 완료: dataset/18/IMG_5978.HEIC -> dataset/18/3.jpg
# 변환 완료: dataset/18/IMG_5977.HEIC -> dataset/18/4.jpg
# 변환 완료: dataset/18/IMG_8372.JPG -> dataset/18/5.jpg
# 변환 완료: dataset/18/IMG_8373.JPG -> dataset/18/6.jpg
# 변환 완료: dataset/18/IMG_5971.HEIC -> dataset/18/7.jpg
# 변환 완료: dataset/18/IMG_6154.HEIC -> dataset/18/8.jpg
# 변환 완료: dataset/18/IMG_5976.HEIC -> dataset/18/9.jpg
# 변환 완료: dataset/18/IMG_5975.HEIC -> dataset/18/10.jpg
# 변환 완료: dataset/18/IMG_6153.HEIC -> dataset/18/11.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/19
# 변환 완료: dataset/19/IMG_5987.HEIC -> dataset/19/0.jpg
# 변환 완료: dataset/19/IMG_5979.HEIC -> dataset/19/1.jpg
# 변환 완료: dataset/19/IMG_5508.JPG -> dataset/19/2.jpg
# 변환 완료: dataset/19/IMG_5988.HEIC -> dataset/19/3.jpg
# 변환 완료: dataset/19/IMG_5507.JPG -> dataset/19/4.jpg
# 변환 완료: dataset/19/IMG_5980.HEIC -> dataset/19/5.jpg
# 변환 완료: dataset/19/IMG_5986.HEIC -> dataset/19/6.jpg
# 변환 완료: dataset/19/IMG_5982.HEIC -> dataset/19/7.jpg
# 변환 완료: dataset/19/IMG_5973.HEIC -> dataset/19/8.jpg
# 변환 완료: dataset/19/IMG_5984.HEIC -> dataset/19/9.jpg
# 변환 완료: dataset/19/IMG_8375.JPG -> dataset/19/10.jpg
# 변환 완료: dataset/19/IMG_5974.HEIC -> dataset/19/11.jpg
# 변환 완료: dataset/19/IMG_5981.HEIC -> dataset/19/12.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/20
# 변환 완료: dataset/20/IMG_6068.HEIC -> dataset/20/0.jpg
# 변환 완료: dataset/20/IMG_6066.HEIC -> dataset/20/1.jpg
# 변환 완료: dataset/20/IMG_5510.JPG -> dataset/20/2.jpg
# 변환 완료: dataset/20/IMG_6065.HEIC -> dataset/20/3.jpg
# 변환 완료: dataset/20/IMG_6067.HEIC -> dataset/20/4.jpg
# 변환 완료: dataset/20/IMG_6071.HEIC -> dataset/20/5.jpg
# 변환 완료: dataset/20/IMG_6072.HEIC -> dataset/20/6.jpg
# 변환 완료: dataset/20/IMG_6073.HEIC -> dataset/20/7.jpg
# 변환 완료: dataset/20/IMG_6070.HEIC -> dataset/20/8.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/21
# 변환 완료: dataset/21/IMG_6050.HEIC -> dataset/21/0.jpg
# 변환 완료: dataset/21/IMG_6058.HEIC -> dataset/21/1.jpg
# 변환 완료: dataset/21/IMG_6055.HEIC -> dataset/21/2.jpg
# 변환 완료: dataset/21/IMG_6054.HEIC -> dataset/21/3.jpg
# 변환 완료: dataset/21/IMG_6052.HEIC -> dataset/21/4.jpg
# 변환 완료: dataset/21/IMG_6051.HEIC -> dataset/21/5.jpg
# 변환 완료: dataset/21/IMG_6056.HEIC -> dataset/21/6.jpg
# 변환 완료: dataset/21/IMG_6053.HEIC -> dataset/21/7.jpg
# 변환 완료: dataset/21/IMG_6057.HEIC -> dataset/21/8.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/22
# 변환 완료: dataset/22/IMG_6143.HEIC -> dataset/22/0.jpg
# 변환 완료: dataset/22/IMG_6146.HEIC -> dataset/22/1.jpg
# 변환 완료: dataset/22/IMG_6145.HEIC -> dataset/22/2.jpg
# 변환 완료: dataset/22/IMG_5509.JPG -> dataset/22/3.jpg
# 변환 완료: dataset/22/IMG_6144.HEIC -> dataset/22/4.jpg
# 변환 완료: dataset/22/IMG_6147.HEIC -> dataset/22/5.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/23
# 변환 완료: dataset/23/IMG_5989.HEIC -> dataset/23/0.jpg
# 변환 완료: dataset/23/IMG_5995.HEIC -> dataset/23/1.jpg
# 변환 완료: dataset/23/IMG_5991.HEIC -> dataset/23/2.jpg
# 변환 완료: dataset/23/IMG_6002.HEIC -> dataset/23/3.jpg
# 변환 완료: dataset/23/IMG_5983.HEIC -> dataset/23/4.jpg
# 변환 완료: dataset/23/IMG_6011.HEIC -> dataset/23/5.jpg
# 변환 완료: dataset/23/IMG_5511.JPG -> dataset/23/6.jpg
# 변환 완료: dataset/23/IMG_5985.HEIC -> dataset/23/7.jpg
# 변환 완료: dataset/23/IMG_5994.HEIC -> dataset/23/8.jpg
# 변환 완료: dataset/23/IMG_5512.JPG -> dataset/23/9.jpg
# 변환 완료: dataset/23/IMG_6005.HEIC -> dataset/23/10.jpg
# 변환 완료: dataset/23/IMG_5990.HEIC -> dataset/23/11.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/24
# 변환 완료: dataset/24/IMG_6061.HEIC -> dataset/24/0.jpg
# 변환 완료: dataset/24/IMG_6063.HEIC -> dataset/24/1.jpg
# 변환 완료: dataset/24/IMG_6060.HEIC -> dataset/24/2.jpg
# 변환 완료: dataset/24/IMG_6062.HEIC -> dataset/24/3.jpg
# 변환 완료: dataset/24/IMG_6059.HEIC -> dataset/24/4.jpg
# 변환 완료: dataset/24/IMG_6064.HEIC -> dataset/24/5.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/25
# 변환 완료: dataset/25/IMG_6039.HEIC -> dataset/25/0.jpg
# 변환 완료: dataset/25/IMG_6043.HEIC -> dataset/25/1.jpg
# 변환 완료: dataset/25/IMG_6042.HEIC -> dataset/25/2.jpg
# 변환 완료: dataset/25/IMG_6040.HEIC -> dataset/25/3.jpg
# 변환 완료: dataset/25/IMG_6041.HEIC -> dataset/25/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/26
# 변환 완료: dataset/26/IMG_6034.HEIC -> dataset/26/0.jpg
# 변환 완료: dataset/26/IMG_6033.HEIC -> dataset/26/1.jpg
# 변환 완료: dataset/26/IMG_6035.HEIC -> dataset/26/2.jpg
# 변환 완료: dataset/26/IMG_6030.HEIC -> dataset/26/3.jpg
# 변환 완료: dataset/26/IMG_5514.JPG -> dataset/26/4.jpg
# 변환 완료: dataset/26/IMG_6038.HEIC -> dataset/26/5.jpg
# 변환 완료: dataset/26/IMG_6036.HEIC -> dataset/26/6.jpg
# 변환 완료: dataset/26/IMG_6032.HEIC -> dataset/26/7.jpg
# 변환 완료: dataset/26/IMG_6037.HEIC -> dataset/26/8.jpg
# 변환 완료: dataset/26/IMG_6031.HEIC -> dataset/26/9.jpg
# 변환 완료: dataset/26/IMG_6045.HEIC -> dataset/26/10.jpg
# 변환 완료: dataset/26/IMG_6044.HEIC -> dataset/26/11.jpg
# 변환 완료: dataset/26/IMG_6046.HEIC -> dataset/26/12.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/27
# 변환 완료: dataset/27/IMG_6022.HEIC -> dataset/27/0.jpg
# 변환 완료: dataset/27/IMG_6020.HEIC -> dataset/27/1.jpg
# 변환 완료: dataset/27/IMG_6017.HEIC -> dataset/27/2.jpg
# 변환 완료: dataset/27/IMG_6024.HEIC -> dataset/27/3.jpg
# 변환 완료: dataset/27/IMG_5515.JPG -> dataset/27/4.jpg
# 변환 완료: dataset/27/IMG_6018.HEIC -> dataset/27/5.jpg
# 변환 완료: dataset/27/IMG_6023.HEIC -> dataset/27/6.jpg
# 변환 완료: dataset/27/IMG_6021.HEIC -> dataset/27/7.jpg
# 변환 완료: dataset/27/IMG_6026.HEIC -> dataset/27/8.jpg
# 변환 완료: dataset/27/IMG_5518.JPG -> dataset/27/9.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/28
# 변환 완료: dataset/28/IMG_6008.HEIC -> dataset/28/0.jpg
# 변환 완료: dataset/28/IMG_6010.HEIC -> dataset/28/1.jpg
# 변환 완료: dataset/28/IMG_6013.HEIC -> dataset/28/2.jpg
# 변환 완료: dataset/28/IMG_6015.HEIC -> dataset/28/3.jpg
# 변환 완료: dataset/28/IMG_5516.JPG -> dataset/28/4.jpg
# 변환 완료: dataset/28/IMG_6012.HEIC -> dataset/28/5.jpg
# 변환 완료: dataset/28/IMG_6014.HEIC -> dataset/28/6.jpg
# 변환 완료: dataset/28/IMG_6009.HEIC -> dataset/28/7.jpg
# 변환 완료: dataset/28/IMG_6007.HEIC -> dataset/28/8.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/29
# 변환 완료: dataset/29/IMG_6004.HEIC -> dataset/29/0.jpg
# 변환 완료: dataset/29/IMG_5993.HEIC -> dataset/29/1.jpg
# 변환 완료: dataset/29/IMG_6006.HEIC -> dataset/29/2.jpg
# 변환 완료: dataset/29/IMG_5992.HEIC -> dataset/29/3.jpg
# 변환 완료: dataset/29/IMG_6001.HEIC -> dataset/29/4.jpg
# 변환 완료: dataset/29/IMG_5517.JPG -> dataset/29/5.jpg
# 변환 완료: dataset/29/IMG_6003.HEIC -> dataset/29/6.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/30
# 변환 완료: dataset/30/20241124_164638.jpg -> dataset/30/0.jpg
# 변환 완료: dataset/30/20241105_144918.jpg -> dataset/30/1.jpg
# 변환 완료: dataset/30/20241124_164312.jpg -> dataset/30/2.jpg
# 변환 완료: dataset/30/20241124_164648.jpg -> dataset/30/3.jpg
# 변환 완료: dataset/30/20241124_164402.jpg -> dataset/30/4.jpg
# 변환 완료: dataset/30/20241124_164343.jpg -> dataset/30/5.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/31
# 변환 완료: dataset/31/20241105_144300.jpg -> dataset/31/0.jpg
# 변환 완료: dataset/31/20241124_165154.jpg -> dataset/31/1.jpg
# 변환 완료: dataset/31/20241124_165223.jpg -> dataset/31/2.jpg
# 변환 완료: dataset/31/20241124_164057.jpg -> dataset/31/3.jpg
# 변환 완료: dataset/31/20241124_165126.jpg -> dataset/31/4.jpg
# 변환 완료: dataset/31/20241124_165251.jpg -> dataset/31/5.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/32
# 변환 완료: dataset/32/20241124_161747.jpg -> dataset/32/0.jpg
# 변환 완료: dataset/32/20241124_165025.jpg -> dataset/32/1.jpg
# 변환 완료: dataset/32/20241105_144022.jpg -> dataset/32/2.jpg
# 변환 완료: dataset/32/20241124_165013.jpg -> dataset/32/3.jpg
# 변환 완료: dataset/32/20241124_165109.jpg -> dataset/32/4.jpg
# 변환 완료: dataset/32/20241124_165036.jpg -> dataset/32/5.jpg
# 변환 완료: dataset/32/20241124_165051.jpg -> dataset/32/6.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/33
# 변환 완료: dataset/33/20241124_164854.jpg -> dataset/33/0.jpg
# 변환 완료: dataset/33/20241124_164720.jpg -> dataset/33/1.jpg
# 변환 완료: dataset/33/20241124_164759.jpg -> dataset/33/2.jpg
# 변환 완료: dataset/33/20241124_164827.jpg -> dataset/33/3.jpg
# 변환 완료: dataset/33/20241124_164738.jpg -> dataset/33/4.jpg
# 변환 완료: dataset/33/20241124_164943.jpg -> dataset/33/5.jpg
# 변환 완료: dataset/33/20241105_144648.jpg -> dataset/33/6.jpg
# 변환 완료: dataset/33/20241124_164920.jpg -> dataset/33/7.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/34
# 변환 완료: dataset/34/20241124_164413.jpg -> dataset/34/0.jpg
# 변환 완료: dataset/34/20241105_144754.jpg -> dataset/34/1.jpg
# 변환 완료: dataset/34/20241124_164332.jpg -> dataset/34/2.jpg
# 변환 완료: dataset/34/20241124_164318.jpg -> dataset/34/3.jpg
# 변환 완료: dataset/34/20241124_164427.jpg -> dataset/34/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/35
# 변환 완료: dataset/35/20241124_164019.jpg -> dataset/35/0.jpg
# 변환 완료: dataset/35/20241105_145027.jpg -> dataset/35/1.jpg
# 변환 완료: dataset/35/20241124_164218.jpg -> dataset/35/2.jpg
# 변환 완료: dataset/35/20241124_164125.jpg -> dataset/35/3.jpg
# 변환 완료: dataset/35/20241124_164300.jpg -> dataset/35/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/36
# 변환 완료: dataset/36/20241105_145432.jpg -> dataset/36/0.jpg
# 변환 완료: dataset/36/20241124_163623.jpg -> dataset/36/1.jpg
# 변환 완료: dataset/36/20241105_145251.jpg -> dataset/36/2.jpg
# 변환 완료: dataset/36/20241124_163647.jpg -> dataset/36/3.jpg
# 변환 완료: dataset/36/20241124_163705.jpg -> dataset/36/4.jpg
# 변환 완료: dataset/36/20241124_163808.jpg -> dataset/36/5.jpg
# 변환 완료: dataset/36/20241124_163825.jpg -> dataset/36/6.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/37
# 변환 완료: dataset/37/20241105_144303.jpg -> dataset/37/0.jpg
# 변환 완료: dataset/37/20241124_162144.jpg -> dataset/37/1.jpg
# 변환 완료: dataset/37/20241105_144334.jpg -> dataset/37/2.jpg
# 변환 완료: dataset/37/20241124_165210.jpg -> dataset/37/3.jpg
# 변환 완료: dataset/37/20241124_165059.jpg -> dataset/37/4.jpg
# 변환 완료: dataset/37/20241124_162316.jpg -> dataset/37/5.jpg
# 변환 완료: dataset/37/20241124_165238.jpg -> dataset/37/6.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/38
# 변환 완료: dataset/38/20241124_162338.jpg -> dataset/38/0.jpg
# 변환 완료: dataset/38/20241124_162401.jpg -> dataset/38/1.jpg
# 변환 완료: dataset/38/20241124_162412.jpg -> dataset/38/2.jpg
# 변환 완료: dataset/38/20241124_162342.jpg -> dataset/38/3.jpg
# 변환 완료: dataset/38/20241105_145822.jpg -> dataset/38/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/39
# 변환 완료: dataset/39/20241124_163542.jpg -> dataset/39/0.jpg
# 변환 완료: dataset/39/20241105_145311.jpg -> dataset/39/1.jpg
# 변환 완료: dataset/39/20241124_163440.jpg -> dataset/39/2.jpg
# 변환 완료: dataset/39/20241124_163601.jpg -> dataset/39/3.jpg
# 변환 완료: dataset/39/20241124_163503.jpg -> dataset/39/4.jpg
# 변환 완료: dataset/39/20241124_163522.jpg -> dataset/39/5.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/40
# 변환 완료: dataset/40/20241105_144455.jpg -> dataset/40/0.jpg
# 변환 완료: dataset/40/20241124_164135.jpg -> dataset/40/1.jpg
# 변환 완료: dataset/40/20241124_164151.jpg -> dataset/40/2.jpg
# 변환 완료: dataset/40/20241125_131355.jpg -> dataset/40/3.jpg
# 변환 완료: dataset/40/20241009_160401.jpg -> dataset/40/4.jpg
# 변환 완료: dataset/40/20241125_131340.jpg -> dataset/40/5.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/41
# 변환 완료: dataset/41/20241105_144212.jpg -> dataset/41/0.jpg
# 변환 완료: dataset/41/20241124_165438.jpg -> dataset/41/1.jpg
# 변환 완료: dataset/41/20241124_165452.jpg -> dataset/41/2.jpg
# 변환 완료: dataset/41/20241105_144150.jpg -> dataset/41/3.jpg
# 변환 완료: dataset/41/20241124_165504.jpg -> dataset/41/4.jpg
# 변환 완료: dataset/41/20241124_161915.jpg -> dataset/41/5.jpg
# 변환 완료: dataset/41/20241124_161859.jpg -> dataset/41/6.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/42
# 변환 완료: dataset/42/20241105_144308.jpg -> dataset/42/0.jpg
# 변환 완료: dataset/42/20241124_165333.jpg -> dataset/42/1.jpg
# 변환 완료: dataset/42/20241124_165301.jpg -> dataset/42/2.jpg
# 변환 완료: dataset/42/20241105_144445.jpg -> dataset/42/3.jpg
# 변환 완료: dataset/42/20241124_165323.jpg -> dataset/42/4.jpg
# 변환 완료: dataset/42/20241124_165343.jpg -> dataset/42/5.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/43
# 변환 완료: dataset/43/20241124_163036.jpg -> dataset/43/0.jpg
# 변환 완료: dataset/43/20241124_163046.jpg -> dataset/43/1.jpg
# 변환 완료: dataset/43/20241124_163041.jpg -> dataset/43/2.jpg
# 변환 완료: dataset/43/20241124_163031.jpg -> dataset/43/3.jpg
# 변환 완료: dataset/43/20241105_150608.jpg -> dataset/43/4.jpg
# 변환 완료: dataset/43/20241105_150559.jpg -> dataset/43/5.jpg
# 변환 완료: dataset/43/20241124_163050.jpg -> dataset/43/6.jpg
# 변환 완료: dataset/43/20241124_163054.jpg -> dataset/43/7.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/44
# 변환 완료: dataset/44/20241124_162930.jpg -> dataset/44/0.jpg
# 변환 완료: dataset/44/20241105_150457.jpg -> dataset/44/1.jpg
# 변환 완료: dataset/44/20241124_162856.jpg -> dataset/44/2.jpg
# 변환 완료: dataset/44/20241124_162941.jpg -> dataset/44/3.jpg
# 변환 완료: dataset/44/20241124_162910.jpg -> dataset/44/4.jpg
# 변환 완료: dataset/44/20241124_162902.jpg -> dataset/44/5.jpg
# 변환 완료: dataset/44/20241124_162922.jpg -> dataset/44/6.jpg
# 변환 완료: dataset/44/20241105_150446.jpg -> dataset/44/7.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/45
# 변환 완료: dataset/45/20241105_145643.jpg -> dataset/45/0.jpg
# 변환 완료: dataset/45/20241124_162649.jpg -> dataset/45/1.jpg
# 변환 완료: dataset/45/20241124_162635.jpg -> dataset/45/2.jpg
# 변환 완료: dataset/45/20241105_150321.jpg -> dataset/45/3.jpg
# 변환 완료: dataset/45/20241124_162655.jpg -> dataset/45/4.jpg
# 변환 완료: dataset/45/20241105_145645.jpg -> dataset/45/5.jpg
# 변환 완료: dataset/45/20241124_162627.jpg -> dataset/45/6.jpg
# 변환 완료: dataset/45/20241124_162710.jpg -> dataset/45/7.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/46
# 변환 완료: dataset/46/20241124_162507.jpg -> dataset/46/0.jpg
# 변환 완료: dataset/46/20241105_145726.jpg -> dataset/46/1.jpg
# 변환 완료: dataset/46/20241124_162525.jpg -> dataset/46/2.jpg
# 변환 완료: dataset/46/20241124_162534.jpg -> dataset/46/3.jpg
# 변환 완료: dataset/46/20241124_162519.jpg -> dataset/46/4.jpg
# 변환 완료: dataset/46/20241105_145733.jpg -> dataset/46/5.jpg
# 변환 완료: dataset/46/20241105_145746.jpg -> dataset/46/6.jpg
# 변환 완료: dataset/46/20241124_162513.jpg -> dataset/46/7.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/47
# 변환 완료: dataset/47/20241124_162024.jpg -> dataset/47/0.jpg
# 변환 완료: dataset/47/20241124_162033.jpg -> dataset/47/1.jpg
# 변환 완료: dataset/47/20241124_162044.jpg -> dataset/47/2.jpg
# 변환 완료: dataset/47/20241124_162029.jpg -> dataset/47/3.jpg
# 변환 완료: dataset/47/20241124_162019.jpg -> dataset/47/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/48
# 변환 완료: dataset/48/20241124_161951.jpg -> dataset/48/0.jpg
# 변환 완료: dataset/48/20241124_162152.jpg -> dataset/48/1.jpg
# 변환 완료: dataset/48/20241124_162157.jpg -> dataset/48/2.jpg
# 변환 완료: dataset/48/20241124_161959.jpg -> dataset/48/3.jpg
# 변환 완료: dataset/48/20241105_144950.jpg -> dataset/48/4.jpg
# 변환 완료: dataset/48/20241124_162009.jpg -> dataset/48/5.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/49
# 변환 완료: dataset/49/20241124_162208.jpg -> dataset/49/0.jpg
# 변환 완료: dataset/49/20241105_144653.jpg -> dataset/49/1.jpg
# 변환 완료: dataset/49/20241124_162216.jpg -> dataset/49/2.jpg
# 변환 완료: dataset/49/20241105_144652.jpg -> dataset/49/3.jpg
# 변환 완료: dataset/49/20241124_162220.jpg -> dataset/49/4.jpg
# 변환 완료: dataset/49/20241105_144850.jpg -> dataset/49/5.jpg
# 변환 완료: dataset/49/20241105_144750.jpg -> dataset/49/6.jpg
# 변환 완료: dataset/49/20241124_162213.jpg -> dataset/49/7.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/50
# 변환 완료: dataset/50/20241124_162241.jpg -> dataset/50/0.jpg
# 변환 완료: dataset/50/20241124_162304.jpg -> dataset/50/1.jpg
# 변환 완료: dataset/50/20241105_144650.jpg -> dataset/50/2.jpg
# 변환 완료: dataset/50/20241124_162058.jpg -> dataset/50/3.jpg
# 변환 완료: dataset/50/20241124_162053.jpg -> dataset/50/4.jpg
# 변환 완료: dataset/50/20241124_162105.jpg -> dataset/50/5.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/51
# 변환 완료: dataset/51/20241105_145056.jpg -> dataset/51/0.jpg
# 변환 완료: dataset/51/20241105_145215.jpg -> dataset/51/1.jpg
# 변환 완료: dataset/51/20241124_164042.jpg -> dataset/51/2.jpg
# 변환 완료: dataset/51/20241124_164006.jpg -> dataset/51/3.jpg
# 변환 완료: dataset/51/20241124_164027.jpg -> dataset/51/4.jpg
# 변환 완료: dataset/51/20241124_164045.jpg -> dataset/51/5.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/52
# 변환 완료: dataset/52/20241124_163935.jpg -> dataset/52/0.jpg
# 변환 완료: dataset/52/20241124_163902.jpg -> dataset/52/1.jpg
# 변환 완료: dataset/52/20241124_163251.jpg -> dataset/52/2.jpg
# 변환 완료: dataset/52/20241124_163917.jpg -> dataset/52/3.jpg
# 변환 완료: dataset/52/20241105_145405.jpg -> dataset/52/4.jpg
# 변환 완료: dataset/52/20241124_163745.jpg -> dataset/52/5.jpg
# 변환 완료: dataset/52/20241124_163307.jpg -> dataset/52/6.jpg
# 변환 완료: dataset/52/20241124_163832.jpg -> dataset/52/7.jpg
# 변환 완료: dataset/52/20241124_163340.jpg -> dataset/52/8.jpg
# 변환 완료: dataset/52/20241124_163952.jpg -> dataset/52/9.jpg
# 변환 완료: dataset/52/20241124_163850.jpg -> dataset/52/10.jpg
# 변환 완료: dataset/52/20241124_163322.jpg -> dataset/52/11.jpg
# 변환 완료: dataset/52/20241124_163224.jpg -> dataset/52/12.jpg
# 변환 완료: dataset/52/20241124_163236.jpg -> dataset/52/13.jpg
# 변환 완료: dataset/52/20241124_163712.jpg -> dataset/52/14.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/53
# 변환 완료: dataset/53/20241124_164550.jpg -> dataset/53/0.jpg
# 변환 완료: dataset/53/20241124_164510.jpg -> dataset/53/1.jpg
# 변환 완료: dataset/53/20241124_164456.jpg -> dataset/53/2.jpg
# 변환 완료: dataset/53/20241124_164541.jpg -> dataset/53/3.jpg
# 변환 완료: dataset/53/20241124_164525.jpg -> dataset/53/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/54
# 변환 완료: dataset/54/20241124_164222.jpg -> dataset/54/0.jpg
# 변환 완료: dataset/54/20241105_145015.jpg -> dataset/54/1.jpg
# 변환 완료: dataset/54/20241124_164239.jpg -> dataset/54/2.jpg
# 변환 완료: dataset/54/20241124_164230.jpg -> dataset/54/3.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/55
# 변환 완료: dataset/55/20241125_131234.jpg -> dataset/55/0.jpg
# 변환 완료: dataset/55/20241105_144939.jpg -> dataset/55/1.jpg
# 변환 완료: dataset/55/20241125_131225.jpg -> dataset/55/2.jpg
# 변환 완료: dataset/55/20241105_144958.jpg -> dataset/55/3.jpg
# 변환 완료: dataset/55/20241125_131249.jpg -> dataset/55/4.jpg
# 변환 완료: dataset/55/20241124_164248.jpg -> dataset/55/5.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/56
# 변환 완료: dataset/56/20241128_153343.jpg -> dataset/56/0.jpg
# 변환 완료: dataset/56/20241128_153326.jpg -> dataset/56/1.jpg
# 변환 완료: dataset/56/20241128_153316.jpg -> dataset/56/2.jpg
# 변환 완료: dataset/56/20241128_153303.jpg -> dataset/56/3.jpg
# 변환 완료: dataset/56/20241128_153339.jpg -> dataset/56/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/57
# 변환 완료: dataset/57/20241128_153418.jpg -> dataset/57/0.jpg
# 변환 완료: dataset/57/20241128_153456.jpg -> dataset/57/1.jpg
# 변환 완료: dataset/57/20241128_153441.jpg -> dataset/57/2.jpg
# 변환 완료: dataset/57/20241128_153413.jpg -> dataset/57/3.jpg
# 변환 완료: dataset/57/20241128_153459.jpg -> dataset/57/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/58
# 변환 완료: dataset/58/20241128_153528.jpg -> dataset/58/0.jpg
# 변환 완료: dataset/58/20241128_153543.jpg -> dataset/58/1.jpg
# 변환 완료: dataset/58/20241128_153539.jpg -> dataset/58/2.jpg
# 변환 완료: dataset/58/20241128_153514.jpg -> dataset/58/3.jpg
# 변환 완료: dataset/58/20241128_153517.jpg -> dataset/58/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/59
# 변환 완료: dataset/59/20241128_153641.jpg -> dataset/59/0.jpg
# 변환 완료: dataset/59/20241128_153602.jpg -> dataset/59/1.jpg
# 변환 완료: dataset/59/20241128_153619.jpg -> dataset/59/2.jpg
# 변환 완료: dataset/59/20241128_153636.jpg -> dataset/59/3.jpg
# 변환 완료: dataset/59/20241128_153557.jpg -> dataset/59/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/60
# 변환 완료: dataset/60/20241128_153733.jpg -> dataset/60/0.jpg
# 변환 완료: dataset/60/20241128_153730.jpg -> dataset/60/1.jpg
# 변환 완료: dataset/60/20241128_153711.jpg -> dataset/60/2.jpg
# 변환 완료: dataset/60/20241128_153720.jpg -> dataset/60/3.jpg
# 변환 완료: dataset/60/20241128_153706.jpg -> dataset/60/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/61
# 변환 완료: dataset/61/20241128_153809.jpg -> dataset/61/0.jpg
# 변환 완료: dataset/61/20241128_153806.jpg -> dataset/61/1.jpg
# 변환 완료: dataset/61/20241128_153822.jpg -> dataset/61/2.jpg
# 변환 완료: dataset/61/20241128_153844.jpg -> dataset/61/3.jpg
# 변환 완료: dataset/61/20241128_153838.jpg -> dataset/61/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/62
# 변환 완료: dataset/62/20241128_153915.jpg -> dataset/62/0.jpg
# 변환 완료: dataset/62/20241128_153937.jpg -> dataset/62/1.jpg
# 변환 완료: dataset/62/20241128_153933.jpg -> dataset/62/2.jpg
# 변환 완료: dataset/62/20241128_153925.jpg -> dataset/62/3.jpg
# 변환 완료: dataset/62/20241128_153911.jpg -> dataset/62/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/63
# 변환 완료: dataset/63/20241128_154036.jpg -> dataset/63/0.jpg
# 변환 완료: dataset/63/20241128_153948.jpg -> dataset/63/1.jpg
# 변환 완료: dataset/63/20241128_153952.jpg -> dataset/63/2.jpg
# 변환 완료: dataset/63/20241128_154031.jpg -> dataset/63/3.jpg
# 변환 완료: dataset/63/20241128_154008.jpg -> dataset/63/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/64
# 변환 완료: dataset/64/20241126_170500.jpg -> dataset/64/0.jpg
# 변환 완료: dataset/64/20241126_170355.jpg -> dataset/64/1.jpg
# 변환 완료: dataset/64/20241126_170441.jpg -> dataset/64/2.jpg
# 변환 완료: dataset/64/20241126_170506.jpg -> dataset/64/3.jpg
# 변환 완료: dataset/64/20241126_170346.jpg -> dataset/64/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/65
# 변환 완료: dataset/65/20241126_170608.jpg -> dataset/65/0.jpg
# 변환 완료: dataset/65/20241126_170619.jpg -> dataset/65/1.jpg
# 변환 완료: dataset/65/20241126_170555.jpg -> dataset/65/2.jpg
# 변환 완료: dataset/65/20241126_170623.jpg -> dataset/65/3.jpg
# 변환 완료: dataset/65/20241126_170559.jpg -> dataset/65/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/66
# 변환 완료: dataset/66/20241126_170731.jpg -> dataset/66/0.jpg
# 변환 완료: dataset/66/20241126_170646.jpg -> dataset/66/1.jpg
# 변환 완료: dataset/66/20241126_170650.jpg -> dataset/66/2.jpg
# 변환 완료: dataset/66/20241126_170706.jpg -> dataset/66/3.jpg
# 변환 완료: dataset/66/20241126_170727.jpg -> dataset/66/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/67
# 변환 완료: dataset/67/20241126_170809.jpg -> dataset/67/0.jpg
# 변환 완료: dataset/67/20241126_170758.jpg -> dataset/67/1.jpg
# 변환 완료: dataset/67/20241126_170754.jpg -> dataset/67/2.jpg
# 변환 완료: dataset/67/20241126_170840.jpg -> dataset/67/3.jpg
# 변환 완료: dataset/67/20241126_170831.jpg -> dataset/67/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/68
# 변환 완료: dataset/68/20241128_151331.jpg -> dataset/68/0.jpg
# 변환 완료: dataset/68/20241128_151339.jpg -> dataset/68/1.jpg
# 변환 완료: dataset/68/20241128_151356.jpg -> dataset/68/2.jpg
# 변환 완료: dataset/68/20241128_151325.jpg -> dataset/68/3.jpg
# 변환 완료: dataset/68/20241128_151352.jpg -> dataset/68/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/69
# 변환 완료: dataset/69/20241128_151424.jpg -> dataset/69/0.jpg
# 변환 완료: dataset/69/20241128_151430.jpg -> dataset/69/1.jpg
# 변환 완료: dataset/69/20241128_151458.jpg -> dataset/69/2.jpg
# 변환 완료: dataset/69/20241128_151452.jpg -> dataset/69/3.jpg
# 변환 완료: dataset/69/20241128_151443.jpg -> dataset/69/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/70
# 변환 완료: dataset/70/20241128_151511.jpg -> dataset/70/0.jpg
# 변환 완료: dataset/70/20241128_151536.jpg -> dataset/70/1.jpg
# 변환 완료: dataset/70/20241128_151516.jpg -> dataset/70/2.jpg
# 변환 완료: dataset/70/20241128_151602.jpg -> dataset/70/3.jpg
# 변환 완료: dataset/70/20241128_151558.jpg -> dataset/70/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/71
# 변환 완료: dataset/71/20241128_151657.jpg -> dataset/71/0.jpg
# 변환 완료: dataset/71/20241128_151614.jpg -> dataset/71/1.jpg
# 변환 완료: dataset/71/20241128_151636.jpg -> dataset/71/2.jpg
# 변환 완료: dataset/71/20241128_151653.jpg -> dataset/71/3.jpg
# 변환 완료: dataset/71/20241128_151619.jpg -> dataset/71/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/72
# 변환 완료: dataset/72/20241126_165808.jpg -> dataset/72/0.jpg
# 변환 완료: dataset/72/20241126_165812.jpg -> dataset/72/1.jpg
# 변환 완료: dataset/72/20241126_165734.jpg -> dataset/72/2.jpg
# 변환 완료: dataset/72/20241126_165727.jpg -> dataset/72/3.jpg
# 변환 완료: dataset/72/20241126_165756.jpg -> dataset/72/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/73
# 변환 완료: dataset/73/20241126_165904.jpg -> dataset/73/0.jpg
# 변환 완료: dataset/73/20241126_165853.jpg -> dataset/73/1.jpg
# 변환 완료: dataset/73/20241126_165847.jpg -> dataset/73/2.jpg
# 변환 완료: dataset/73/20241126_165927.jpg -> dataset/73/3.jpg
# 변환 완료: dataset/73/20241126_165923.jpg -> dataset/73/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/74
# 변환 완료: dataset/74/20241126_170004.jpg -> dataset/74/0.jpg
# 변환 완료: dataset/74/20241126_170017.jpg -> dataset/74/1.jpg
# 변환 완료: dataset/74/20241126_165953.jpg -> dataset/74/2.jpg
# 변환 완료: dataset/74/20241126_165947.jpg -> dataset/74/3.jpg
# 변환 완료: dataset/74/20241126_170012.jpg -> dataset/74/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/75
# 변환 완료: dataset/75/20241126_170041.jpg -> dataset/75/0.jpg
# 변환 완료: dataset/75/20241126_170054.jpg -> dataset/75/1.jpg
# 변환 완료: dataset/75/20241126_170102.jpg -> dataset/75/2.jpg
# 변환 완료: dataset/75/20241126_170046.jpg -> dataset/75/3.jpg
# 변환 완료: dataset/75/20241126_170106.jpg -> dataset/75/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/76
# 변환 완료: dataset/76/20241126_165237.jpg -> dataset/76/0.jpg
# 변환 완료: dataset/76/20241126_165231.jpg -> dataset/76/1.jpg
# 변환 완료: dataset/76/20241126_165226.jpg -> dataset/76/2.jpg
# 변환 완료: dataset/76/20241126_165222.jpg -> dataset/76/3.jpg
# 변환 완료: dataset/76/20241126_165216.jpg -> dataset/76/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/77
# 변환 완료: dataset/77/20241126_165135.jpg -> dataset/77/0.jpg
# 변환 완료: dataset/77/20241126_165139.jpg -> dataset/77/1.jpg
# 변환 완료: dataset/77/20241126_165148.jpg -> dataset/77/2.jpg
# 변환 완료: dataset/77/20241126_165143.jpg -> dataset/77/3.jpg
# 변환 완료: dataset/77/20241126_165153.jpg -> dataset/77/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/78
# 변환 완료: dataset/78/20241128_152227.jpg -> dataset/78/0.jpg
# 변환 완료: dataset/78/20241128_152303.jpg -> dataset/78/1.jpg
# 변환 완료: dataset/78/20241128_152255.jpg -> dataset/78/2.jpg
# 변환 완료: dataset/78/20241128_152240.jpg -> dataset/78/3.jpg
# 변환 완료: dataset/78/20241128_152215.jpg -> dataset/78/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/79
# 변환 완료: dataset/79/20241128_152350.jpg -> dataset/79/0.jpg
# 변환 완료: dataset/79/20241128_152334.jpg -> dataset/79/1.jpg
# 변환 완료: dataset/79/20241128_152338.jpg -> dataset/79/2.jpg
# 변환 완료: dataset/79/20241128_152407.jpg -> dataset/79/3.jpg
# 변환 완료: dataset/79/20241128_152411.jpg -> dataset/79/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/80
# 변환 완료: dataset/80/20241128_152521.jpg -> dataset/80/0.jpg
# 변환 완료: dataset/80/20241128_152538.jpg -> dataset/80/1.jpg
# 변환 완료: dataset/80/20241128_152526.jpg -> dataset/80/2.jpg
# 변환 완료: dataset/80/20241128_152554.jpg -> dataset/80/3.jpg
# 변환 완료: dataset/80/20241128_152551.jpg -> dataset/80/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/81
# 변환 완료: dataset/81/20241128_152750.jpg -> dataset/81/0.jpg
# 변환 완료: dataset/81/20241128_152711.jpg -> dataset/81/1.jpg
# 변환 완료: dataset/81/20241128_152737.jpg -> dataset/81/2.jpg
# 변환 완료: dataset/81/20241128_152745.jpg -> dataset/81/3.jpg
# 변환 완료: dataset/81/20241128_152718.jpg -> dataset/81/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/82
# 변환 완료: dataset/82/20241128_160552.jpg -> dataset/82/0.jpg
# 변환 완료: dataset/82/20241128_160547.jpg -> dataset/82/1.jpg
# 변환 완료: dataset/82/20241128_160612.jpg -> dataset/82/2.jpg
# 변환 완료: dataset/82/20241128_160616.jpg -> dataset/82/3.jpg
# 변환 완료: dataset/82/20241128_160556.jpg -> dataset/82/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/83
# 변환 완료: dataset/83/20241128_160442.jpg -> dataset/83/0.jpg
# 변환 완료: dataset/83/20241128_160437.jpg -> dataset/83/1.jpg
# 변환 완료: dataset/83/20241128_160447.jpg -> dataset/83/2.jpg
# 변환 완료: dataset/83/20241128_160433.jpg -> dataset/83/3.jpg
# 변환 완료: dataset/83/20241128_160450.jpg -> dataset/83/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/84
# 변환 완료: dataset/84/20241126_164422.jpg -> dataset/84/0.jpg
# 변환 완료: dataset/84/20241126_164411.jpg -> dataset/84/1.jpg
# 변환 완료: dataset/84/20241126_164404.jpg -> dataset/84/2.jpg
# 변환 완료: dataset/84/20241126_164444.jpg -> dataset/84/3.jpg
# 변환 완료: dataset/84/20241126_164433.jpg -> dataset/84/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/85
# 변환 완료: dataset/85/20241126_164609.jpg -> dataset/85/0.jpg
# 변환 완료: dataset/85/20241126_164526.jpg -> dataset/85/1.jpg
# 변환 완료: dataset/85/20241126_164535.jpg -> dataset/85/2.jpg
# 변환 완료: dataset/85/20241126_164554.jpg -> dataset/85/3.jpg
# 변환 완료: dataset/85/20241126_164547.jpg -> dataset/85/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/86
# 변환 완료: dataset/86/20241126_164907.jpg -> dataset/86/0.jpg
# 변환 완료: dataset/86/20241126_164811.jpg -> dataset/86/1.jpg
# 변환 완료: dataset/86/20241126_164820.jpg -> dataset/86/2.jpg
# 변환 완료: dataset/86/20241126_164839.jpg -> dataset/86/3.jpg
# 변환 완료: dataset/86/20241126_164913.jpg -> dataset/86/4.jpg
# 이름 변경 및 포맷 변환 완료.
# ./dataset/87
# 변환 완료: dataset/87/20241126_165034.jpg -> dataset/87/0.jpg
# 변환 완료: dataset/87/20241126_165039.jpg -> dataset/87/1.jpg
# 변환 완료: dataset/87/20241126_165120.jpg -> dataset/87/2.jpg
# 변환 완료: dataset/87/20241126_165114.jpg -> dataset/87/3.jpg
# 변환 완료: dataset/87/20241126_165055.jpg -> dataset/87/4.jpg
# 이름 변경 및 포맷 변환 완료.

# %% [markdown]
# **10시간 고민했던 문제 !!!**
#
#
# <br>
# DataLoader에서는 dataset 내부 폴더들의 이름을 y값으로 지정함.
#
# 하지만 엄밀히 따지자면 이름들을 idx로 바꿔서 저장.
#
#
# 이때, 이름들을 str로 취급.
#
# 그래서 classification을 할 경우, bird, apple, lion 3개의 폴더에 각각의 이미지가 있을 때, model의 output값에서 0번째 index는 apple이 될 것. 사전식 정렬을 해서 class(이름들) to idx(index값)로 변경해서, 저장하기 때문임.
#
# 나는 0부터 87까지의 이름을 갖는 총 88개의 폴더를 생성했지만, 여기서 모델이 예측을 하면 꼭 일관적으로(같은 클래스의 이미지들은 다 같은 클래스를 예측) 틀린 클래스를 예측했다. 하지만 training과 test 결과는 좋았다. 꼭 개별 이미지를 사용해서 예측한 결과만 이상했다.
#
# 이유가 폴더 명이 str형식이어서, 0, 1, 2, 3, 4, 순서로 idx도 동일하게 생성된 것이 아니라 0, 1, 10, 11, 형식으로 취급해서 이것들이 0, 1, 2, 3, 4로 저장되었기 때문이다.
#
# 이것을 확인하는 class to idx가 다음고 같다.

# %%
from torchvision import datasets

# 데이터셋 로드
dataset = datasets.ImageFolder(root='./dataset')

# 폴더 이름과 레이블 번호 매핑 확인
print(dataset.class_to_idx)


# 매핑을 뒤집기
idx_to_class = {v: int(k) for k, v in class_to_idx.items()}

# 예측된 값 -> 원래 클래스 이름으로 변환
def get_original_class(predicted_label):
    """
    예측된 숫자를 원래 폴더 이름으로 변환
    :param predicted_label: 모델이 예측한 레이블 (int)
    :return: 원래 폴더 이름 (str)
    """
    return idx_to_class.get(predicted_label, "Unknown")  # 존재하지 않는 레이블이면 "Unknown" 반환
# Out:
# {'0': 0, '1': 1, '10': 2, '11': 3, '12': 4, '13': 5, '14': 6, '15': 7, '16': 8, '17': 9, '18': 10, '19': 11, '2': 12, '20': 13, '21': 14, '22': 15, '23': 16, '24': 17, '25': 18, '26': 19, '27': 20, '28': 21, '29': 22, '3': 23, '30': 24, '31': 25, '32': 26, '33': 27, '34': 28, '35': 29, '36': 30, '37': 31, '38': 32, '39': 33, '4': 34, '40': 35, '41': 36, '42': 37, '43': 38, '44': 39, '45': 40, '46': 41, '47': 42, '48': 43, '49': 44, '5': 45, '50': 46, '51': 47, '52': 48, '53': 49, '54': 50, '55': 51, '56': 52, '57': 53, '58': 54, '59': 55, '6': 56, '60': 57, '61': 58, '62': 59, '63': 60, '64': 61, '65': 62, '66': 63, '67': 64, '68': 65, '69': 66, '7': 67, '70': 68, '71': 69, '72': 70, '73': 71, '74': 72, '75': 73, '76': 74, '77': 75, '78': 76, '79': 77, '8': 78, '80': 79, '81': 80, '82': 81, '83': 82, '84': 83, '85': 84, '86': 85, '87': 86, '9': 87}

# %%
import os
import torch
from torch.utils.data import DataLoader, random_split
from torchvision import transforms
from torchvision.datasets.folder import make_dataset, default_loader

# 숫자 순서로 폴더를 정렬하도록 커스텀 Dataset 생성
class NumericFolderDataset(torch.utils.data.Dataset):
    def __init__(self, root, transform=None, target_transform=None, loader=default_loader):
        self.root = root
        self.transform = transform
        self.target_transform = target_transform
        self.loader = loader

        # 폴더 이름을 숫자 순으로 정렬
        self.classes, self.class_to_idx = self._find_classes_numeric_order(root)
        self.samples = make_dataset(root, self.class_to_idx, extensions=None, is_valid_file=None)

    def _find_classes_numeric_order(self, directory):
        classes = sorted([d for d in os.listdir(directory) if os.path.isdir(os.path.join(directory, d))], key=int)
        class_to_idx = {cls_name: i for i, cls_name in enumerate(classes)}
        return classes, class_to_idx

    def __getitem__(self, index):
        path, target = self.samples[index]
        sample = self.loader(path)
        if self.transform is not None:
            sample = self.transform(sample)
        if self.target_transform is not None:
            target = self.target_transform(target)
        return sample, target

    def __len__(self):
        return len(self.samples)

# Augmentation 설정
torch.manual_seed(42)
train_transforms = transforms.Compose([
    transforms.Resize((224, 224)),  # 이미지를 224x224로 크기 변경 (비율 유지)
    transforms.RandomHorizontalFlip(),  # 좌우 반전
    transforms.RandomRotation(15),  # 최대 15도 회전
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),  # 밝기/대비 조정
    transforms.ToTensor(),  # Tensor로 변환
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # 정규화
])

test_transforms = transforms.Compose([
    transforms.Resize((224, 224)),  # 테스트 데이터는 크기만 조정
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# 데이터셋 로드
dataset_path = './dataset'  # 데이터셋 경로
dataset = NumericFolderDataset(root=dataset_path, transform=None)

# 데이터셋 분할 (Train/Test 8:2 비율)
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

# 각각에 Transform 적용
train_dataset.dataset.transform = train_transforms
test_dataset.dataset.transform = test_transforms

# DataLoader 생성
batch_size = 32  # 배치 크기
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# 확인
print("클래스 맵핑:", dataset.class_to_idx)
print(f"Train 데이터 크기: {len(train_dataset)}")
print(f"Test 데이터 크기: {len(test_dataset)}")

# %%
# for debug

for x, y in train_loader:
  print(x.shape)
  print(y)
  break
# Out:
# torch.Size([32, 3, 224, 224])
# tensor([ 2, 17,  9,  1,  0, 82, 34, 58, 33, 23, 55, 86, 12,  3, 87, 12, 77, 31,
#         31, 23, 33,  1, 57, 21, 28, 29, 73, 67, 23, 67, 46,  2])

# %% [markdown]
# ## **Model**

# %%
# %%writefile mymodel.py

from torchvision import models
import torch
import torch.nn as nn


# Model
class Custom_ResNet(nn.Module) :
  def __init__(self):
    super().__init__()

    self.resnet = models.resnet18(pretrained=True)

    for p in self.resnet.parameters():
      p.requires_grad = False

    # add layer
    self.resnet.fc = torch.nn.Identity()

    self.fc_mid = nn.Linear(512, 256)  # New fully connected layer

    self.resnet.fc_building = nn.Linear(256, 88)


  def forward(self, x):
    out = self.resnet(x)
    out = torch.relu(self.fc_mid(out))
    building_class = self.resnet.fc_building(out)

    return building_class
# Out:
# Overwriting mymodel.py

# %% [markdown]
# ## **Train**

# %%
import torch.optim.lr_scheduler as lr_scheduler
import torch.nn.functional as F
import torch
from building_info import get_building_label
from mymodel import Custom_ResNet

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

model = Custom_ResNet()
model = model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.99)
criterion = nn.CrossEntropyLoss()


# Epochs 설정
num_epochs = 35

num_classes = 88
best_acc = 0.0

for epoch in range(num_epochs):
  model.train()
  for x, y in train_loader:
    x, y = x.to(device), y.to(device)

    out = model(x)
    loss = criterion(out, y)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

  model.eval()
  sec1_correct = 0.0
  sec2_correct = 0.0
  val_loss = 0.0


  with torch.no_grad():
    for x, y in test_loader:
      x, y = x.to(device), y.to(device)

      out = model(x)
      out = F.softmax(out, dim=1)
      # print(out)

      # print(out.argmax(1).float(), y)


      # Section 1 - Predict appropriate subclass -> correct
      sec1_correct += (out.argmax(1) == y).float().sum().item()
      val_loss += criterion(out, y).item()

      # Section 2 - Add all probability of subclasses and Pick the best one for test
      batch, sub_class = out.shape

      # print(batch, sub_class)

      # 기존 매핑 (class_to_idx)
      class_to_idx = {
          '0': 0, '1': 1, '10': 2, '11': 3, '12': 4, '13': 5, '14': 6, '15': 7, '16': 8, '17': 9, '18': 10, '19': 11,
          '2': 12, '20': 13, '21': 14, '22': 15, '23': 16, '24': 17, '25': 18, '26': 19, '27': 20, '28': 21, '29': 22,
          '3': 23, '30': 24, '31': 25, '32': 26, '33': 27, '34': 28, '35': 29, '36': 30, '37': 31, '38': 32, '39': 33,
          '4': 34, '40': 35, '41': 36, '42': 37, '43': 38, '44': 39, '45': 40, '46': 41, '47': 42, '48': 43, '49': 44,
          '5': 45, '50': 46, '51': 47, '52': 48, '53': 49, '54': 50, '55': 51, '56': 52, '57': 53, '58': 54, '59': 55,
          '6': 56, '60': 57, '61': 58, '62': 59, '63': 60, '64': 61, '65': 62, '66': 63, '67': 64, '68': 65, '69': 66,
          '7': 67, '70': 68, '71': 69, '72': 70, '73': 71, '74': 72, '75': 73, '76': 74, '77': 75, '78': 76, '79': 77,
          '8': 78, '80': 79, '81': 80, '82': 81, '83': 82, '84': 83, '85': 84, '86': 85, '87': 86, '9': 87
      }

      # 매핑을 뒤집기
      idx_to_class = {v: int(k) for k, v in class_to_idx.items()}

      # 예측된 값 -> 원래 클래스 이름으로 변환
      def get_original_class(predicted_label):
          """
          예측된 숫자를 원래 폴더 이름으로 변환
          :param predicted_label: 모델이 예측한 레이블 (int)
          :return: 원래 폴더 이름 (str)
          """
          return idx_to_class.get(predicted_label, "Unknown")  # 존재하지 않는 레이블이면 "Unknown" 반환


      new_out = torch.zeros(batch, 28)
      new_out = new_out.to(device)


      for i in range(batch):
        for j in range(num_classes):
          real_class = get_original_class(j)
          folder_label = get_building_label(real_classes)  # `j`를 폴더 이름으로 변환
          new_out[i][folder_label - 1] += out[i][j]


      # print(new_out)

      #print(y)
      for i in range(batch):
        y[i] = get_building_label(int(y[i]))

      #print(y)
      sec2_correct += (new_out.argmax(1) == y).float().sum().item()


  val_loss_avg = val_loss / len(test_loader)
  sec1_accuracy = 100. * sec1_correct / len(test_loader.dataset)
  sec2_accuracy = 100. * sec2_correct / len(test_loader.dataset)

  #### best.pth 저장하기
  if best_acc < sec1_accuracy:
    best_acc = sec1_accuracy
    torch.save(model.state_dict(), f'./best_weights.pth')
    print(f"Epoch {epoch + 1}: New best accuracy achieved! Model saved.")

  print(f"Epoch {epoch + 1}/{num_epochs} - "
    f"Validation Loss: {val_loss_avg:.4f}, "
    f"Section1 Accuracy: {sec1_accuracy:.2f}%",
    f"Section2 Accuracy: {sec2_accuracy:.2f}%")

  scheduler.step()

torch.save(model.state_dict(), f'./final_weights.pth')
# Out:
# Using device: cuda:0
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1: New best accuracy achieved! Model saved.
# Epoch 1/35 - Validation Loss: 4.4176, Section1 Accuracy: 14.93% Section2 Accuracy: 4.52%
# Epoch 2: New best accuracy achieved! Model saved.
# Epoch 2/35 - Validation Loss: 4.3587, Section1 Accuracy: 35.75% Section2 Accuracy: 5.88%
# Epoch 3: New best accuracy achieved! Model saved.
# Epoch 3/35 - Validation Loss: 4.2669, Section1 Accuracy: 53.85% Section2 Accuracy: 5.88%
# Epoch 4: New best accuracy achieved! Model saved.
# Epoch 4/35 - Validation Loss: 4.1610, Section1 Accuracy: 70.14% Section2 Accuracy: 0.45%

# %% [markdown]
# ## **Test Code**

# %%
import torch
import torch.nn.functional as F
import torchvision.transforms as transforms
import os

from building_info import get_building_label, num_classes, get_building_name
from mymodel import Custom_ResNet
from PIL import Image

# 기존 매핑 (class_to_idx)
class_to_idx = {
    '0': 0, '1': 1, '10': 2, '11': 3, '12': 4, '13': 5, '14': 6, '15': 7, '16': 8, '17': 9, '18': 10, '19': 11,
    '2': 12, '20': 13, '21': 14, '22': 15, '23': 16, '24': 17, '25': 18, '26': 19, '27': 20, '28': 21, '29': 22,
    '3': 23, '30': 24, '31': 25, '32': 26, '33': 27, '34': 28, '35': 29, '36': 30, '37': 31, '38': 32, '39': 33,
    '4': 34, '40': 35, '41': 36, '42': 37, '43': 38, '44': 39, '45': 40, '46': 41, '47': 42, '48': 43, '49': 44,
    '5': 45, '50': 46, '51': 47, '52': 48, '53': 49, '54': 50, '55': 51, '56': 52, '57': 53, '58': 54, '59': 55,
    '6': 56, '60': 57, '61': 58, '62': 59, '63': 60, '64': 61, '65': 62, '66': 63, '67': 64, '68': 65, '69': 66,
    '7': 67, '70': 68, '71': 69, '72': 70, '73': 71, '74': 72, '75': 73, '76': 74, '77': 75, '78': 76, '79': 77,
    '8': 78, '80': 79, '81': 80, '82': 81, '83': 82, '84': 83, '85': 84, '86': 85, '87': 86, '9': 87
}

# 매핑 뒤집기
idx_to_class = {v: int(k) for k, v in class_to_idx.items()}  # 폴더 이름을 숫자로 변환

# 예측된 값 -> 원래 클래스 이름(숫자)으로 변환
def get_original_class(predicted_label):
    """
    예측된 숫자를 원래 폴더 이름(숫자)으로 변환
    :param predicted_label: 모델이 예측한 레이블 (int)
    :return: 원래 폴더 이름 (int)
    """
    return idx_to_class.get(predicted_label, -1)  # 존재하지 않는 레이블이면 -1 반환


def single_img_test(img_path, weight_path):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model = Custom_ResNet()
    model.load_state_dict(torch.load(weight_path, map_location=device))
    model = model.to(device)
    model.eval()  # 평가 모드로 설정

    test_transforms = transforms.Compose([
        transforms.Resize((224, 224)),  # 테스트 데이터는 크기만 조정
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    image_path = img_path  # 테스트 이미지 경로
    img = Image.open(image_path)
    img_tensor = test_transforms(img).unsqueeze(0).to(device)

    with torch.no_grad():
        out = model(img_tensor)
        #print(out.shape)
        out = F.softmax(out, dim=1)

        # Section 1: 예측된 세부 클래스
        #print(out)
        #print(out.argmax(1))
        s1_class_idx = get_original_class(out.argmax(1).item())
        #print(f'{s1_class_idx} - {image_path}')
        s1_building_name = get_building_name(get_building_label(s1_class_idx))

        # Section 2: 새로운 클래스 구성 (건물별 확률 합산)
        batch, subclass = out.shape
        new_out = torch.zeros(batch, 28).to(device)

        for i in range(batch):
            for j in range(num_classes):
                folder_label = get_building_label(get_original_class(j))
                new_out[i][folder_label-1] += out[i][j]

        s2_class_idx = new_out.argmax(1).item()
        s2_building_name = get_building_name(s2_class_idx+1)

    print(f"Image Path: {image_path}",
          f"Section 1 - Predicted Detailed Class: {s1_building_name}",
          f"Section 2 - Predicted General Class: {s2_building_name}")
    #return s1_class_idx, s2_class_idx
    # s1_class_idx : section1 subclass 예측
    # s1_building_name : section1 building name output
    # s2_class_idx : section2 building class 합산 예측
    # s2_building_name : section2 building name output

img_dir = './testset'   # testdataset directory path
weight_path = './pth/8_weights.pth' #model weight path


image_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff')  # 원하는 확장자 추가 가능
image_paths = [os.path.join(img_dir, f) for f in os.listdir(img_dir) if f.endswith(image_extensions)]

for image in image_paths:
    single_img_test(image, weight_path)
